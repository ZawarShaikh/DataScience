# %%
import pandas as pd

# %% [markdown]
# !------------------------------------ Analysing dataset types and split of classes -------------------------------------!

# %% [markdown]
# Checking the type of the file

# %%
# Open and read the file
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-Honeypot-Capture-7-1/somfy-01/bro/conn.log.labeled', 'r') as file:
    for line in file:
        print(line.strip())  # Use strip() to remove any leading/trailing whitespace or newlines
# Out:
# #separator \x09
# #set_separator	,
# #empty_field	(empty)
# #unset_field	-
# #path	conn
# #open	2019-07-09-11-28-26
# #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
# #types	time	string	addr	port	addr	port	enum	string	interval	count	count	string	bool	bool	count	string	count	count	count	count	set[string]   string   string
# 1562159819.172195	CUg3u41D8SwgQw1Job	0.0.0.0	68	255.255.255.255	67	udp	dhcp	30.004642	8768	0	S0	-	-	0	D	16	9216	0	0	-   benign   -
# 1562159849.173340	CUpk9Y381SJuOHyK2d	255.255.255.255	68	192.168.1.1	67	udp	dhcp	0.004564	0	3900	SHR	-	-	0	^d	0	0	13	4264	-   benign   -
# 1562159953.959669	CC5CQA3Ptzma7a0by4	fe80::5bcc:698e:39d5:cdf	5353	ff02::fb	5353	udp	dns	3.948539	876	0	S0	-	-	0	D	6	1164	0	0	-   benign   -
# ...

# %%
import pandas as pd

# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled', 'r') as file:
    lines = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx = next(i for i, line in enumerate(lines) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header = lines[header_idx].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled', sep='\t', comment='#', names=header, skiprows=header_idx + 1)

# Display the first few rows of the dataframe
df.head()
# Out:
#              ts                 uid      id.orig_h  id.orig_p  \
# 0  1.540469e+09  CGm6jB4dXK71ZDWUDh  192.168.1.132      58687
# 1  1.540469e+09  CnaDAG3n5r8eiG4su2  192.168.1.132       1900
# 2  1.540469e+09  CUrxU238nt0m6yTgKf  192.168.1.132      32893
# 3  1.540470e+09  CGQf8t1kjdxB5PHXL4  192.168.1.132      53395
# 4  1.540470e+09  CUo9DH2QDnCaBIGjkg  192.168.1.132      52801
#
#          id.resp_h  id.resp_p proto service    duration orig_bytes  ...  \
# 0     216.239.35.4        123   udp       -    0.114184         48  ...
# 1  239.255.255.250       1900   udp       -  160.367579       7536  ...
# 2     216.239.35.8        123   udp       -    0.016986         48  ...
# 3       2.16.60.82        443   tcp       -    0.003497          0  ...
# 4      192.168.1.1         53   udp     dns    0.036724         34  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         SF          -          -            0       Dd         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       452 non-null    float64
#  1   uid                                      452 non-null    object
#  2   id.orig_h                                452 non-null    object
#  3   id.orig_p                                452 non-null    int64
#  4   id.resp_h                                452 non-null    object
#  5   id.resp_p                                452 non-null    int64
#  6   proto                                    452 non-null    object
#  7   service                                  452 non-null    object
#  8   duration                                 452 non-null    object
#  9   orig_bytes                               452 non-null    object
# ...

# %%
df['tunnel_parents   label   detailed-label'].value_counts()
# Out:
# tunnel_parents   label   detailed-label
# -   benign   -    452
# Name: count, dtype: int64

# %% [markdown]
# DF - 2

# %%
# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled', 'r') as file:
    lines2 = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx2 = next(i for i, line in enumerate(lines) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header2 = lines[header_idx2].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df2 = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled', sep='\t', comment='#', names=header2, skiprows=header_idx2 + 1)

# Display the first few rows of the dataframe
df2.head()
# Out:
#              ts                 uid                  id.orig_h  id.orig_p  \
# 0  1.537523e+09   CJAF5z3MDFg4XVDXB                    0.0.0.0         68
# 1  1.537523e+09  CcYEFX3Qj9xdNX1ZCa                192.168.2.1       5353
# 2  1.537523e+09  CF6fCK1nFqvI1XxGM1  fe80::80e6:50ff:fe12:1464       5353
# 3  1.537523e+09  C2dlio3MkdwWJ80y04             169.254.15.115       5353
# 4  1.537523e+09  COrF0t2uLErai9nfH5                    0.0.0.0         68
#
#          id.resp_h  id.resp_p proto service   duration orig_bytes  ...  \
# 0  255.255.255.255         67   udp    dhcp   8.322388        600  ...
# 1      224.0.0.251       5353   udp     dns          -          -  ...
# 2         ff02::fb       5353   udp     dns          -          -  ...
# 3      224.0.0.251       5353   udp     dns          -          -  ...
# 4  255.255.255.255         67   udp    dhcp  60.555587       3000  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1374 entries, 0 to 1373
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       1374 non-null   float64
#  1   uid                                      1374 non-null   object
#  2   id.orig_h                                1374 non-null   object
#  3   id.orig_p                                1374 non-null   int64
#  4   id.resp_h                                1374 non-null   object
#  5   id.resp_p                                1374 non-null   int64
#  6   proto                                    1374 non-null   object
#  7   service                                  1374 non-null   object
#  8   duration                                 1374 non-null   object
#  9   orig_bytes                               1374 non-null   object
# ...

# %%
df2['tunnel_parents   label   detailed-label'].value_counts()
# Out:
# tunnel_parents   label   detailed-label
# -   benign   -    1374
# Name: count, dtype: int64

# %% [markdown]
# DF - 3

# %%
# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled', 'r') as file:
    lines3 = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx3 = next(i for i, line in enumerate(lines) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header3 = lines[header_idx3].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df3 = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-Honeypot-Capture-7-1/Somfy-01/bro/conn.log.labeled', sep='\t', comment='#', names=header3, skiprows=header_idx3 + 1)

# Display the first few rows of the dataframe
df3.head()
# Out:
#              ts                 uid                  id.orig_h  id.orig_p  \
# 0  1.562160e+09  CUg3u41D8SwgQw1Job                    0.0.0.0         68
# 1  1.562160e+09  CUpk9Y381SJuOHyK2d            255.255.255.255         68
# 2  1.562160e+09  CC5CQA3Ptzma7a0by4   fe80::5bcc:698e:39d5:cdf       5353
# 3  1.562160e+09   C3sgcmfvNzjNoY0Kd   fe80::5bcc:698e:39d5:cdf       5353
# 4  1.562160e+09   CJVaCgoBTEsu0jjDi  fe80::4eef:c0ff:fe27:561e       5353
#
#          id.resp_h  id.resp_p proto service   duration  orig_bytes  ...  \
# 0  255.255.255.255         67   udp    dhcp  30.004642        8768  ...
# 1      192.168.1.1         67   udp    dhcp   0.004564           0  ...
# 2         ff02::fb       5353   udp     dns   3.948539         876  ...
# 3         ff02::fb       5353   udp     dns   3.768179         876  ...
# 4         ff02::fb       5353   udp     dns   0.000114         451  ...
#
#    conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       130 non-null    float64
#  1   uid                                      130 non-null    object
#  2   id.orig_h                                130 non-null    object
#  3   id.orig_p                                130 non-null    int64
#  4   id.resp_h                                130 non-null    object
#  5   id.resp_p                                130 non-null    int64
#  6   proto                                    130 non-null    object
#  7   service                                  130 non-null    object
#  8   duration                                 130 non-null    float64
#  9   orig_bytes                               130 non-null    int64
# ...

# %%
df3['tunnel_parents   label   detailed-label'].value_counts()
# Out:
# tunnel_parents   label   detailed-label
# -   benign   -    130
# Name: count, dtype: int64

# %% [markdown]
# df -4

# %%
# Open and read the file
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled', 'r') as file:
    for line in file:
        print(line.strip())  # Use strip() to remove any leading/trailing whitespace or newlines
# Out:
# #separator \x09
# #set_separator	,
# #empty_field	(empty)
# #unset_field	-
# #path	conn
# #open	2018-08-08-12-22-16
# #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
# #types	time	string	addr	port	addr	port	enum	string	interval	count	count	string	bool	bool	count	string	count	count	count	count	set[string]   string   string
# 1533042911.474174	C5JLGOoxIw2dBZt47	192.168.100.113	123	81.2.254.224	123	udp	-	0.005490	48	48	SF	-	-	0	Dd	1	76	1	76	(empty)   Benign   -
# 1533042921.474234	Cf3cHf4jZr9nvD808i	192.168.100.113	123	147.231.100.5	123	udp	-	0.001741	48	48	SF	-	-	0	Dd	1	76	1	76	(empty)   Benign   -
# 1533042944.474388	CJgmSt3bSY6XwE9fzc	192.168.100.113	123	31.31.74.35	123	udp	-	0.004495	48	48	SF	-	-	0	Dd	1	76	1	76	(empty)   Benign   -
# ...

# %%
# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled', 'r') as file:
    lines4 = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx4 = next(i for i, line in enumerate(lines4) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header4 = lines4[header_idx4].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df4 = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled', sep='\t', comment='#', names=header4, skiprows=header_idx4 + 1)

# Display the first few rows of the dataframe
df4.head()
# Out:
#              ts                 uid        id.orig_h  id.orig_p  \
# 0  1.533043e+09   C5JLGOoxIw2dBZt47  192.168.100.113        123
# 1  1.533043e+09  Cf3cHf4jZr9nvD808i  192.168.100.113        123
# 2  1.533043e+09  CJgmSt3bSY6XwE9fzc  192.168.100.113        123
# 3  1.533043e+09  Cav32m4csR3OZYhShj  192.168.100.113        123
# 4  1.533043e+09  ClwPfA40tU9UT4nksg  192.168.100.113        123
#
#         id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0    81.2.254.224        123   udp       -  0.005490         48  ...
# 1   147.231.100.5        123   udp       -  0.001741         48  ...
# 2     31.31.74.35        123   udp       -  0.004495         48  ...
# 3  147.251.48.140        123   udp       -  0.006988         48  ...
# 4   147.231.100.5        123   udp       -  0.001487         48  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         SF          -          -            0       Dd         1
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10403 entries, 0 to 10402
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       10403 non-null  float64
#  1   uid                                      10403 non-null  object
#  2   id.orig_h                                10403 non-null  object
#  3   id.orig_p                                10403 non-null  int64
#  4   id.resp_h                                10403 non-null  object
#  5   id.resp_p                                10403 non-null  int64
#  6   proto                                    10403 non-null  object
#  7   service                                  10403 non-null  object
#  8   duration                                 10403 non-null  object
#  9   orig_bytes                               10403 non-null  object
# ...

# %%
df4['tunnel_parents   label   detailed-label'].value_counts()
# Out:
# tunnel_parents   label   detailed-label
# (empty)   Malicious   C&C    8222
# (empty)   Benign   -         2181
# Name: count, dtype: int64

# %%
df4.to_csv('CTU-IoT-Malware-Capture-8-1.csv')

# %%
# Open and read the file
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled', 'r') as file:
    for line in file:
        print(line.strip())  # Use strip() to remove any leading/trailing whitespace or newlines
# Out:
# #separator \x09
# #set_separator	,
# #empty_field	(empty)
# #unset_field	-
# #path	conn
# #open	2019-10-18-15-06-44
# #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
# #types	time	string	addr	port	addr	port	enum	string	interval	count	count	string	bool	bool	count	string	count	count	count	count	set[string]   string   string
# 1538478769.600293	CSQG794riQ4XnzTxP2	192.168.100.103	37082	192.168.100.1	53	udp	dns	5.005151	78	0	S0	-	-	0	D	2	134	0	0	-   Benign   -
# 1538478779.610847	COTbdG2BhtGBlmf6r	192.168.100.103	34486	192.168.100.1	53	udp	dns	0.007243	90	90	SF	-	-	0	Dd	2	146	2	146	-   Benign   -
# 1538478789.630642	CP48WJ2HOnLuGtr5kb	192.168.100.103	37601	192.168.100.1	53	udp	dns	0.002250	90	90	SF	-	-	0	Dd	2	146	2	146	-   Benign   -
# ...

# %%
# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled', 'r') as file:
    lines5 = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx5 = next(i for i, line in enumerate(lines5) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header5 = lines5[header_idx5].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df5 = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled', sep='\t', comment='#', names=header5, skiprows=header_idx5 + 1)

# Display the first few rows of the dataframe
df5.head()
# Out:
#              ts                 uid        id.orig_h  id.orig_p  \
# 0  1.538479e+09  CSQG794riQ4XnzTxP2  192.168.100.103      37082
# 1  1.538479e+09   COTbdG2BhtGBlmf6r  192.168.100.103      34486
# 2  1.538479e+09  CP48WJ2HOnLuGtr5kb  192.168.100.103      37601
# 3  1.538479e+09  CeTMJi2TydRSaVdsG4  192.168.100.103      46439
# 4  1.538479e+09  CZ6ne24AN9WAg9XA9d  192.168.100.103      55174
#
#        id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0  192.168.100.1         53   udp     dns  5.005151         78  ...
# 1  192.168.100.1         53   udp     dns  0.007243         90  ...
# 2  192.168.100.1         53   udp     dns  0.002250         90  ...
# 3  192.168.100.1         53   udp     dns  5.005154         78  ...
# 4  192.168.100.1         53   udp     dns  0.002246         90  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         S0          -          -            0        D         2
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3209 entries, 0 to 3208
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       3209 non-null   float64
#  1   uid                                      3209 non-null   object
#  2   id.orig_h                                3209 non-null   object
#  3   id.orig_p                                3209 non-null   int64
#  4   id.resp_h                                3209 non-null   object
#  5   id.resp_p                                3209 non-null   int64
#  6   proto                                    3209 non-null   object
#  7   service                                  3209 non-null   object
#  8   duration                                 3209 non-null   object
#  9   orig_bytes                               3209 non-null   object
# ...

# %%
df5['tunnel_parents   label   detailed-label'].value_counts()
# Out:
# tunnel_parents   label   detailed-label
# -   Benign   -               3193
# -   Malicious   C&C-Torii      16
# Name: count, dtype: int64

# %%
df5.to_csv('CTU-IoT-Malware-Capture-20-1.csv')

# %%
# Open and read the file
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled', 'r') as file:
    for line in file:
        print(line.strip())  # Use strip() to remove any leading/trailing whitespace or newlines
# Out:
# #separator \x09
# #set_separator	,
# #empty_field	(empty)
# #unset_field	-
# #path	conn
# #open	2019-10-20-00-50-06
# #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
# #types	time	string	addr	port	addr	port	enum	string	interval	count	count	string	bool	bool	count	string	count	count	count	count	set[string]   string   string
# 1538572953.710599	Cu3Tieri43IPsyBO3	192.168.100.113	42789	192.168.100.1	53	udp	dns	-	-	-	S0	-	-	0	D	1	67	0	0	-   Benign   -
# 1538572958.715995	Cbetl72NeXczaqQ8Lj	192.168.100.113	60546	192.168.100.1	53	udp	dns	0.001494	90	90	SF	-	-	0	Dd	2	146	2	146	-   Benign   -
# 1538572982.666603	CUmQWl2ZA2hrbNtohe	192.168.100.113	37320	192.168.100.1	53	udp	dns	5.005135	78	0	S0	-	-	0	D	2	134	0	0	-   Benign   -
# ...

# %%
# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled', 'r') as file:
    lines6 = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx6 = next(i for i, line in enumerate(lines6) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header6 = lines6[header_idx6].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df6 = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-21-1/bro/conn.log.labeled', sep='\t', comment='#', names=header6, skiprows=header_idx6 + 1)

# Display the first few rows of the dataframe
df6.head()
# Out:
#              ts                 uid        id.orig_h  id.orig_p  \
# 0  1.538573e+09   Cu3Tieri43IPsyBO3  192.168.100.113      42789
# 1  1.538573e+09  Cbetl72NeXczaqQ8Lj  192.168.100.113      60546
# 2  1.538573e+09  CUmQWl2ZA2hrbNtohe  192.168.100.113      37320
# 3  1.538573e+09   C9oEZWtG35wx1Mqq5  192.168.100.113      51338
# 4  1.538573e+09  CbhqpU1oZZyrP7PE6i  192.168.100.113      60088
#
#        id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0  192.168.100.1         53   udp     dns         -          -  ...
# 1  192.168.100.1         53   udp     dns  0.001494         90  ...
# 2  192.168.100.1         53   udp     dns  5.005135         78  ...
# 3  192.168.100.1         53   udp     dns  0.001483         90  ...
# 4  192.168.100.1         53   udp     dns  5.038625        117  ...
#
#   conn_state local_orig local_resp missed_bytes  history orig_pkts  \
# 0         S0          -          -            0        D         1
# ...

# %%
print(df6.info())

print(df6['tunnel_parents   label   detailed-label'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3286 entries, 0 to 3285
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       3286 non-null   float64
#  1   uid                                      3286 non-null   object
#  2   id.orig_h                                3286 non-null   object
#  3   id.orig_p                                3286 non-null   int64
#  4   id.resp_h                                3286 non-null   object
#  5   id.resp_p                                3286 non-null   int64
#  6   proto                                    3286 non-null   object
#  7   service                                  3286 non-null   object
#  8   duration                                 3286 non-null   object
#  9   orig_bytes                               3286 non-null   object
# ...

# %%
df6.to_csv('CTU-IoT-Malware-Capture-21-1.csv')

# %%
# Open and read the file
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled', 'r') as file:
    for line in file:
        print(line.strip())  # Use strip() to remove any leading/trailing whitespace or newlines
# Out:
# #separator \x09
# #set_separator	,
# #empty_field	(empty)
# #unset_field	-
# #path	conn
# #open	2019-01-11-05-34-44
# #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
# #types	time	string	addr	port	addr	port	enum	string	interval	count	count	string	bool	bool	count	string	count	count	count	count	set[string]   string   string
# 1547127288.026074	CXY5uG2sSmjJ0grfY2	192.168.1.197	58312	104.24.96.120	80	tcp	http	3.909013	83	67212	SF	-	-	4380	ShADadttFf	54	3371	50	69224	-   Malicious   FileDownload
# 1547127288.018828	Ce3AJzwzXwM3Z1XBg	192.168.1.197	45082	104.24.97.120	80	tcp	http	4.767024	150	67212	SF	-	-	0	ShADadttFf	54	2938	50	69224	-   Malicious   C&C-FileDownload
# 1547127292.857808	CJgnSb3XpbbOcMHKUd	192.168.1.197	58316	104.24.96.120	80	tcp	-	3.107228	0	0	S0	-	-	0	S	3	180	0	0	-   Benign   -
# ...

# %%
# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled', 'r') as file:
    lines7 = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx7 = next(i for i, line in enumerate(lines7) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header7 = lines7[header_idx7].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df7 = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-42-1/bro/conn.log.labeled', sep='\t', comment='#', names=header7, skiprows=header_idx7 + 1)

# Display the first few rows of the dataframe
df7.head()
# Out:
#              ts                 uid      id.orig_h  id.orig_p      id.resp_h  \
# 0  1.547127e+09  CXY5uG2sSmjJ0grfY2  192.168.1.197      58312  104.24.96.120
# 1  1.547127e+09   Ce3AJzwzXwM3Z1XBg  192.168.1.197      45082  104.24.97.120
# 2  1.547127e+09  CJgnSb3XpbbOcMHKUd  192.168.1.197      58316  104.24.96.120
# 3  1.547127e+09   Cq43w4aHlsW8nXZ3l  192.168.1.197      59357    192.168.1.1
# 4  1.547127e+09  C5uLwl2hGy10y9PSr6  192.168.1.197      39686    192.168.1.1
#
#    id.resp_p proto service  duration orig_bytes  ... conn_state local_orig  \
# 0         80   tcp    http  3.909013         83  ...         SF          -
# 1         80   tcp    http  4.767024        150  ...         SF          -
# 2         80   tcp       -  3.107228          0  ...         S0          -
# 3         53   udp     dns  0.029483         58  ...         SF          -
# 4         53   udp     dns  0.001249         58  ...         SF          -
#
# ...

# %%
print(df7.info())

print(df7['tunnel_parents   label   detailed-label'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4426 entries, 0 to 4425
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       4426 non-null   float64
#  1   uid                                      4426 non-null   object
#  2   id.orig_h                                4426 non-null   object
#  3   id.orig_p                                4426 non-null   int64
#  4   id.resp_h                                4426 non-null   object
#  5   id.resp_p                                4426 non-null   int64
#  6   proto                                    4426 non-null   object
#  7   service                                  4426 non-null   object
#  8   duration                                 4426 non-null   object
#  9   orig_bytes                               4426 non-null   object
# ...

# %%
# Open and read the file
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled', 'r') as file:
    for line in file:
        print(line.strip())  # Use strip() to remove any leading/trailing whitespace or newlines
# Out:
# #separator \x09
# #set_separator	,
# #empty_field	(empty)
# #unset_field	-
# #path	conn
# #open	2019-01-11-05-49-40
# #fields	ts	uid	id.orig_h	id.orig_p	id.resp_h	id.resp_p	proto	service	duration	orig_bytes	resp_bytes	conn_state	local_orig	local_resp	missed_bytes	history	orig_pkts	orig_ip_bytes	resp_pkts	resp_ip_bytes	tunnel_parents   label   detailed-label
# #types	time	string	addr	port	addr	port	enum	string	interval	count	count	string	bool	bool	count	string	count	count	count	count	set[string]   string   string
# 1547150789.067208	CzsY0D4B96NTr8m7ld	192.168.1.199	59222	46.101.251.172	80	tcp	http	1.686784	149	171750	SF	-	-	11584	ShADadttfF	122	7741	122	178102	-   Malicious   C&C-FileDownload
# 1547150790.793723	CGEJbl3RNkmXzmkEd4	192.168.1.199	59224	46.101.251.172	80	tcp	-	3.081233	0	0	S0	-	-	0	S	3	180	0	0	-   Malicious   C&C
# 1547150797.954878	CVMYDw4wnZfqWrOfd	192.168.1.199	59224	46.101.251.172	80	tcp	-	-	-	-	S0	-	-	0	S	1	60	0	0	-   Malicious   C&C
# ...

# %%
# Read the file, skipping lines that start with '#' and properly handling the header
with open('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled', 'r') as file:
    lines8 = file.readlines()

# Find the index where the header starts (line that starts with '#fields')
header_idx8 = next(i for i, line in enumerate(lines8) if line.startswith('#fields'))

# Extract the header by splitting the '#fields' line
header8 = lines8[header_idx8].lstrip('#fields\t').strip().split('\t')

# Now read the file, skipping the metadata, and setting the header
df8 = pd.read_csv('D:/Data Science/Fiverr_Materials_Projects/Haaz_SaudiArabia/Order-2/Dataset-3_IOT23/Malware-Project/IoTScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled', sep='\t', comment='#', names=header8, skiprows=header_idx8 + 1)

# Display the first few rows of the dataframe
df8.head()
# Out:
#              ts                 uid      id.orig_h  id.orig_p       id.resp_h  \
# 0  1.547151e+09  CzsY0D4B96NTr8m7ld  192.168.1.199      59222  46.101.251.172
# 1  1.547151e+09  CGEJbl3RNkmXzmkEd4  192.168.1.199      59224  46.101.251.172
# 2  1.547151e+09   CVMYDw4wnZfqWrOfd  192.168.1.199      59224  46.101.251.172
# 3  1.547151e+09   CXKZmpx40udvITEN2  192.168.1.199      59224  46.101.251.172
# 4  1.547151e+09   CBjcNy4pOh8Xg1H4S  192.168.1.199      59224  46.101.251.172
#
#    id.resp_p proto service  duration orig_bytes  ... conn_state local_orig  \
# 0         80   tcp    http  1.686784        149  ...         SF          -
# 1         80   tcp       -  3.081233          0  ...         S0          -
# 2         80   tcp       -         -          -  ...         S0          -
# 3         80   tcp       -         -          -  ...         S0          -
# 4         80   tcp    http  1.847943        149  ...         SF          -
#
# ...

# %%
print(df8.info())

print(df8['tunnel_parents   label   detailed-label'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ts                                       237 non-null    float64
#  1   uid                                      237 non-null    object
#  2   id.orig_h                                237 non-null    object
#  3   id.orig_p                                237 non-null    int64
#  4   id.resp_h                                237 non-null    object
#  5   id.resp_p                                237 non-null    int64
#  6   proto                                    237 non-null    object
#  7   service                                  237 non-null    object
#  8   duration                                 237 non-null    object
#  9   orig_bytes                               237 non-null    object
# ...
